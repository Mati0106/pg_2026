# %% [markdown]
# Prosze utworzyc liste ['titanic', 'boston', 'iris']
#
# Dla danej listy wybrac tylko boston za pomoca list comprehension
# wczytac plik danych za pomoca panda, uzyc rezultatow z naszej listy uzywajac sciezek z biblioteki pathlib

# %%
/Users/alexpapas/Repositories/pg_2026/datasets/Iris.csv
/Users/alexpapas/Repositories/pg_2026/datasets/boston.csv

# %%
elements = ['iris', 'boston', 'titanic']
output_list = [el for el in elements if el =='Boston']

from pathlib import Path
cwd = Path.cwd()

# cond = zm > 4
# cond2 = zm >= 1

# nowa_lista = [cond, cond2]

any([cond for cond in nowa_lista if cond == True])

path_datases = cwd.joinpath('datasets')

path_output_list = path_datases.joinpath(output_list[0])

# path.parents[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 9
#       5 cwd = Path.cwd()
#       7 path_datases = cwd.joinpath('datasets')
# ----> 9 path_output_list = path_datases.joinpath(output_list[0])
#      11 path.parents[2]
#
# IndexError: list index out of range
